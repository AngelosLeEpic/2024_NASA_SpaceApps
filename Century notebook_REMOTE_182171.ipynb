# %%
# Import libraries
import numpy as np
import pandas as pd
from obspy import read
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 from obspy import read
#       5 from datetime import datetime, timedelta
#       6 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'obspy'

# %%
# data path = where we store the data, plots and catalogue
data_path = "./data/lunar/training/"
raw_data_path = data_path + "data/S12_GradeA/"
catalogue_path = data_path + "catalogs/apollo12_catalog_GradeA_final.csv"
print(catalogue_path)
# Out:
# ./data/lunar/training/catalogs/apollo12_catalog_GradeA_final.csv

# %%
catalogue = pd.read_csv(catalogue_path)

# %%
for index,row in catalogue.iterrows():
    print(f"analysing file: {row[0]}\n")
# Out:
# analysing file: xa.s12.00.mhz.1970-01-19HR00_evid00002
#
# analysing file: xa.s12.00.mhz.1970-03-25HR00_evid00003
#
# analysing file: xa.s12.00.mhz.1970-03-26HR00_evid00004
#
# analysing file: xa.s12.00.mhz.1970-04-25HR00_evid00006
#
# analysing file: xa.s12.00.mhz.1970-04-26HR00_evid00007
#
# analysing file: xa.s12.00.mhz.1970-06-15HR00_evid00008
#
# analysing file: xa.s12.00.mhz.1970-06-26HR00_evid00009
#
# analysing file: xa.s12.00.mhz.1970-07-20HR00_evid00010
#
# analysing file: xa.s12.00.mhz.1970-07-20HR00_evid00011
#
# analysing file: xa.s12.00.mhz.1970-09-26HR00_evid00013
#
# analysing file: xa.s12.00.mhz.1970-10-24HR00_evid00014
#
# analysing file: xa.s12.00.mhz.1970-11-12HR00_evid00015
#
# analysing file: xa.s12.00.mhz.1970-12-11HR00_evid00017
#
# analysing file: xa.s12.00.mhz.1970-12-27HR00_evid00019
#
# analysing file: xa.s12.00.mhz.1970-12-31HR00_evid00021
#
# analysing file: xa.s12.00.mhz.1971-01-15HR00_evid00022
#
# analysing file: xa.s12.00.mhz.1971-01-28HR00_evid00023
#
# analysing file: xa.s12.00.mhz.1971-01-29HR00_evid00024
#
# analysing file: xa.s12.00.mhz.1971-02-09HR00_evid00026
#
# analysing file: xa.s12.00.mhz.1971-03-25HR00_evid00028
#
# analysing file: xa.s12.00.mhz.1971-04-13HR00_evid00029
#
# analysing file: xa.s12.00.mhz.1971-04-17HR00_evid00030
#
# analysing file: xa.s12.00.mhz.1971-05-12HR00_evid00031
#
# analysing file: xa.s12.00.mhz.1971-05-12HR00_evid00032
#
# analysing file: xa.s12.00.mhz.1971-05-13HR00_evid00033
#
# analysing file: xa.s12.00.mhz.1971-05-23HR00_evid00034
#
# analysing file: xa.s12.00.mhz.1971-06-12HR00_evid00035
#
# analysing file: xa.s12.00.mhz.1971-09-25HR00_evid00042
#
# analysing file: xa.s12.00.mhz.1971-10-18HR00_evid00043
#
# analysing file: xa.s12.00.mhz.1971-10-20HR00_evid00044
#
# analysing file: xa.s12.00.mhz.1971-10-31HR00_evid00045
#
# analysing file: xa.s12.00.mhz.1971-11-14HR00_evid00046
#
# analysing file: xa.s12.00.mhz.1972-01-04HR00_evid00049
#
# analysing file: xa.s12.00.mhz.1972-03-12HR00_evid00052
#
# analysing file: xa.s12.00.mhz.1972-05-11HR00_evid00055
#
# analysing file: xa.s12.00.mhz.1972-06-16HR00_evid00060
#
# analysing file: xa.s12.00.mhz.1972-07-17HR00_evid00067
#
# analysing file: xa.s12.00.mhz.1972-07-17HR00_evid00068
#
# analysing file: xa.s12.00.mhz.1972-07-28HR00_evid00070
#
# analysing file: xa.s12.00.mhz.1972-07-31HR00_evid00071
#
# analysing file: xa.s12.00.mhz.1972-12-02HR00_evid00083
#
# analysing file: xa.s12.00.mhz.1972-12-03HR00_evid00084
#
# analysing file: xa.s12.00.mhz.1973-01-18HR00_evid00088
#
# analysing file: xa.s12.00.mhz.1973-01-31HR00_evid00091
#
# analysing file: xa.s12.00.mhz.1973-03-01HR00_evid00093
#
# analysing file: xa.s12.00.mhz.1973-03-13HR00_evid00094
#
# analysing file: xa.s12.00.mhz.1973-03-24HR00_evid00097
#
# analysing file: xa.s12.00.mhz.1973-05-14HR00_evid00104
#
# analysing file: xa.s12.00.mhz.1973-06-05HR00_evid00107
#
# analysing file: xa.s12.00.mhz.1973-06-05HR00_evid00108
#
# analysing file: xa.s12.00.mhz.1973-06-18HR00_evid00109
#
# analysing file: xa.s12.00.mhz.1973-06-27HR00_evid00112
#
# analysing file: xa.s12.00.mhz.1973-07-03HR00_evid00113
#
# analysing file: xa.s12.00.mhz.1973-07-04HR00_evid00114
#
# analysing file: xa.s12.00.mhz.1973-07-20HR00_evid00117
#
# analysing file: xa.s12.00.mhz.1973-07-28HR00_evid00120
#
# analysing file: xa.s12.00.mhz.1973-07-29HR00_evid00121
#
# analysing file: xa.s12.00.mhz.1973-08-21HR00_evid00127
#
# analysing file: xa.s12.00.mhz.1974-01-10HR00_evid00136
#
# analysing file: xa.s12.00.mhz.1974-02-07HR00_evid00137
#
# analysing file: xa.s12.00.mhz.1974-02-12HR00_evid00138
#
# analysing file: xa.s12.00.mhz.1974-03-25HR00_evid00140
#
# analysing file: xa.s12.00.mhz.1974-04-08HR00_evid00141
#
# analysing file: xa.s12.00.mhz.1974-04-19HR00_evid00142
#
# analysing file: xa.s12.00.mhz.1974-04-26HR00_evid00144
#
# analysing file: xa.s12.00.mhz.1974-04-27HR00_evid00145
#
# analysing file: xa.s12.00.mhz.1974-06-25HR00_evid00149
#
# analysing file: xa.s12.00.mhz.1974-07-06HR00_evid00150
#
# analysing file: xa.s12.00.mhz.1974-07-06HR00_evid00151
#
# analysing file: xa.s12.00.mhz.1974-07-11HR00_evid00152
#
# analysing file: xa.s12.00.mhz.1974-07-17HR00_evid00153
#
# analysing file: xa.s12.00.mhz.1974-10-14HR00_evid00156
#
# analysing file: xa.s12.00.mhz.1975-04-12HR00_evid00191
#
# analysing file: xa.s12.00.mhz.1975-05-04HR00_evid00192
#
# analysing file: xa.s12.00.mhz.1975-06-24HR00_evid00196
#
# analysing file: xa.s12.00.mhz.1975-06-26HR00_evid00198
# /tmp/ipykernel_13438/1376350761.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"analysing file: {row[0]}\n")

# %%
catalogue.head(100)
# Out:
#                                   filename time_abs(%Y-%m-%dT%H:%M:%S.%f)  \
# 0   xa.s12.00.mhz.1970-01-19HR00_evid00002     1970-01-19T20:25:00.000000
# 1   xa.s12.00.mhz.1970-03-25HR00_evid00003     1970-03-25T03:32:00.000000
# 2   xa.s12.00.mhz.1970-03-26HR00_evid00004     1970-03-26T20:17:00.000000
# 3   xa.s12.00.mhz.1970-04-25HR00_evid00006     1970-04-25T01:14:00.000000
# 4   xa.s12.00.mhz.1970-04-26HR00_evid00007     1970-04-26T14:29:00.000000
# ..                                     ...                            ...
# 71  xa.s12.00.mhz.1974-10-14HR00_evid00156     1974-10-14T17:43:00.000000
# 72  xa.s12.00.mhz.1975-04-12HR00_evid00191     1975-04-12T18:15:00.000000
# 73  xa.s12.00.mhz.1975-05-04HR00_evid00192     1975-05-04T10:05:00.000000
# 74  xa.s12.00.mhz.1975-06-24HR00_evid00196     1975-06-24T16:03:00.000000
# 75  xa.s12.00.mhz.1975-06-26HR00_evid00198     1975-06-26T03:24:00.000000
#
#     time_rel(sec)       evid    mq_type
# 0         73500.0  evid00002  impact_mq
# 1         12720.0  evid00003  impact_mq
# 2         73020.0  evid00004  impact_mq
# 3          4440.0  evid00006  impact_mq
# 4         52140.0  evid00007    deep_mq
# ..            ...        ...        ...
# 71        63780.0  evid00156  impact_mq
# 72        65700.0  evid00191  impact_mq
# 73        36300.0  evid00192  impact_mq
# 74        57780.0  evid00196  impact_mq
# 75        12240.0  evid00198  impact_mq
#
# [76 rows x 5 columns]

# %%
filenames = catalogue["filename"].to_list()

# %%
print(catalogue["filename"].to_list())
# Out:
# ['xa.s12.00.mhz.1970-01-19HR00_evid00002', 'xa.s12.00.mhz.1970-03-25HR00_evid00003', 'xa.s12.00.mhz.1970-03-26HR00_evid00004', 'xa.s12.00.mhz.1970-04-25HR00_evid00006', 'xa.s12.00.mhz.1970-04-26HR00_evid00007', 'xa.s12.00.mhz.1970-06-15HR00_evid00008', 'xa.s12.00.mhz.1970-06-26HR00_evid00009', 'xa.s12.00.mhz.1970-07-20HR00_evid00010', 'xa.s12.00.mhz.1970-07-20HR00_evid00011', 'xa.s12.00.mhz.1970-09-26HR00_evid00013', 'xa.s12.00.mhz.1970-10-24HR00_evid00014', 'xa.s12.00.mhz.1970-11-12HR00_evid00015', 'xa.s12.00.mhz.1970-12-11HR00_evid00017', 'xa.s12.00.mhz.1970-12-27HR00_evid00019', 'xa.s12.00.mhz.1970-12-31HR00_evid00021', 'xa.s12.00.mhz.1971-01-15HR00_evid00022', 'xa.s12.00.mhz.1971-01-28HR00_evid00023', 'xa.s12.00.mhz.1971-01-29HR00_evid00024', 'xa.s12.00.mhz.1971-02-09HR00_evid00026', 'xa.s12.00.mhz.1971-03-25HR00_evid00028', 'xa.s12.00.mhz.1971-04-13HR00_evid00029', 'xa.s12.00.mhz.1971-04-17HR00_evid00030', 'xa.s12.00.mhz.1971-05-12HR00_evid00031', 'xa.s12.00.mhz.1971-05-12HR00_evid00032', 'xa.s12.00.mhz.1971-05-13HR00_evid00033', 'xa.s12.00.mhz.1971-05-23HR00_evid00034', 'xa.s12.00.mhz.1971-06-12HR00_evid00035', 'xa.s12.00.mhz.1971-09-25HR00_evid00042', 'xa.s12.00.mhz.1971-10-18HR00_evid00043', 'xa.s12.00.mhz.1971-10-20HR00_evid00044', 'xa.s12.00.mhz.1971-10-31HR00_evid00045', 'xa.s12.00.mhz.1971-11-14HR00_evid00046', 'xa.s12.00.mhz.1972-01-04HR00_evid00049', 'xa.s12.00.mhz.1972-03-12HR00_evid00052', 'xa.s12.00.mhz.1972-05-11HR00_evid00055', 'xa.s12.00.mhz.1972-06-16HR00_evid00060', 'xa.s12.00.mhz.1972-07-17HR00_evid00067', 'xa.s12.00.mhz.1972-07-17HR00_evid00068', 'xa.s12.00.mhz.1972-07-28HR00_evid00070', 'xa.s12.00.mhz.1972-07-31HR00_evid00071', 'xa.s12.00.mhz.1972-12-02HR00_evid00083', 'xa.s12.00.mhz.1972-12-03HR00_evid00084', 'xa.s12.00.mhz.1973-01-18HR00_evid00088', 'xa.s12.00.mhz.1973-01-31HR00_evid00091', 'xa.s12.00.mhz.1973-03-01HR00_evid00093', 'xa.s12.00.mhz.1973-03-13HR00_evid00094', 'xa.s12.00.mhz.1973-03-24HR00_evid00097', 'xa.s12.00.mhz.1973-05-14HR00_evid00104', 'xa.s12.00.mhz.1973-06-05HR00_evid00107', 'xa.s12.00.mhz.1973-06-05HR00_evid00108', 'xa.s12.00.mhz.1973-06-18HR00_evid00109', 'xa.s12.00.mhz.1973-06-27HR00_evid00112', 'xa.s12.00.mhz.1973-07-03HR00_evid00113', 'xa.s12.00.mhz.1973-07-04HR00_evid00114', 'xa.s12.00.mhz.1973-07-20HR00_evid00117', 'xa.s12.00.mhz.1973-07-28HR00_evid00120', 'xa.s12.00.mhz.1973-07-29HR00_evid00121', 'xa.s12.00.mhz.1973-08-21HR00_evid00127', 'xa.s12.00.mhz.1974-01-10HR00_evid00136', 'xa.s12.00.mhz.1974-02-07HR00_evid00137', 'xa.s12.00.mhz.1974-02-12HR00_evid00138', 'xa.s12.00.mhz.1974-03-25HR00_evid00140', 'xa.s12.00.mhz.1974-04-08HR00_evid00141', 'xa.s12.00.mhz.1974-04-19HR00_evid00142', 'xa.s12.00.mhz.1974-04-26HR00_evid00144', 'xa.s12.00.mhz.1974-04-27HR00_evid00145', 'xa.s12.00.mhz.1974-06-25HR00_evid00149', 'xa.s12.00.mhz.1974-07-06HR00_evid00150', 'xa.s12.00.mhz.1974-07-06HR00_evid00151', 'xa.s12.00.mhz.1974-07-11HR00_evid00152', 'xa.s12.00.mhz.1974-07-17HR00_evid00153', 'xa.s12.00.mhz.1974-10-14HR00_evid00156', 'xa.s12.00.mhz.1975-04-12HR00_evid00191', 'xa.s12.00.mhz.1975-05-04HR00_evid00192', 'xa.s12.00.mhz.1975-06-24HR00_evid00196', 'xa.s12.00.mhz.1975-06-26HR00_evid00198']

# %%
print(filenames)
# Out:
# 0     xa.s12.00.mhz.1970-01-19HR00_evid00002
# 1     xa.s12.00.mhz.1970-03-25HR00_evid00003
# 2     xa.s12.00.mhz.1970-03-26HR00_evid00004
# 3     xa.s12.00.mhz.1970-04-25HR00_evid00006
# 4     xa.s12.00.mhz.1970-04-26HR00_evid00007
#                        ...
# 71    xa.s12.00.mhz.1974-10-14HR00_evid00156
# 72    xa.s12.00.mhz.1975-04-12HR00_evid00191
# 73    xa.s12.00.mhz.1975-05-04HR00_evid00192
# 74    xa.s12.00.mhz.1975-06-24HR00_evid00196
# 75    xa.s12.00.mhz.1975-06-26HR00_evid00198
# Name: filename, Length: 76, dtype: object
